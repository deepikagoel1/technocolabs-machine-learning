# %% [markdown]
# **This notebook is an exercise in the [Introduction to Machine Learning](https://www.kaggle.com/learn/intro-to-machine-learning) course.  You can reference the tutorial at [this link](https://www.kaggle.com/dansbecker/your-first-machine-learning-model).**
#
# ---

# %% [markdown]
# ## Recap
# So far, you have loaded your data and reviewed it with the following code. Run this cell to set up your coding environment where the previous step left off.

# %%
# Code you have previously used to load data
import pandas as pd

# Path of the file to read
iowa_file_path = '../input/home-data-for-ml-course/train.csv'

home_data = pd.read_csv(iowa_file_path)

# Set up code checking
from learntools.core import binder
binder.bind(globals())
from learntools.machine_learning.ex3 import *

print("Setup Complete")
# Out:
# Setup Complete

# %%
home_data.shape
# Out:
# (1460, 81)

# %% [markdown]
# miss_val = 0
# for i in home_data.columns:
#     if home_data[home_data[i].isnull() == True]:
#         miss_val += 1
# print("missing values")

# %% [markdown]
# # Exercises
#
# ## Step 1: Specify Prediction Target
# Select the target variable, which corresponds to the sales price. Save this to a new variable called `y`. You'll need to print a list of the columns to find the name of the column you need.

# %%
# print the list of columns in the dataset to find the name of the prediction target
for i in home_data.columns:
    print(f"\n Column Name: {i} Counts: {home_data[i].value_counts()} \n")
# Out:
#  Column Name: Id Counts: 1       1
# 982     1
# 980     1
# 979     1
# 978     1
#        ..
# 485     1
# 484     1
# 483     1
# 482     1
# 1460    1
# Name: Id, Length: 1460, dtype: int64
#
#
#  Column Name: MSSubClass Counts: 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: MSSubClass, dtype: int64
#
#
#  Column Name: MSZoning Counts: RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64
#
#
#  Column Name: LotFrontage Counts: 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
#         ...
# 112.0      1
# 138.0      1
# 149.0      1
# 38.0       1
# 111.0      1
# Name: LotFrontage, Length: 110, dtype: int64
#
#
#  Column Name: LotArea Counts: 7200     25
# 9600     24
# 6000     17
# 8400     14
# 9000     14
#          ..
# 13031     1
# 10991     1
# 8944      1
# 6897      1
# 8190      1
# Name: LotArea, Length: 1073, dtype: int64
#
#
#  Column Name: Street Counts: Pave    1454
# Grvl       6
# Name: Street, dtype: int64
#
#
#  Column Name: Alley Counts: Grvl    50
# Pave    41
# Name: Alley, dtype: int64
#
#
#  Column Name: LotShape Counts: Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: LotShape, dtype: int64
#
#
#  Column Name: LandContour Counts: Lvl    1311
# Bnk      63
# HLS      50
# Low      36
# Name: LandContour, dtype: int64
#
#
#  Column Name: Utilities Counts: AllPub    1459
# NoSeWa       1
# Name: Utilities, dtype: int64
#
#
#  Column Name: LotConfig Counts: Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Name: LotConfig, dtype: int64
#
#
#  Column Name: LandSlope Counts: Gtl    1382
# Mod      65
# Sev      13
# Name: LandSlope, dtype: int64
#
#
#  Column Name: Neighborhood Counts: NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# Timber      38
# IDOTRR      37
# ClearCr     28
# SWISU       25
# StoneBr     25
# Blmngtn     17
# MeadowV     17
# BrDale      16
# Veenker     11
# NPkVill      9
# Blueste      2
# Name: Neighborhood, dtype: int64
#
#
#  Column Name: Condition1 Counts: Norm      1260
# Feedr       81
# Artery      48
# RRAn        26
# PosN        19
# RRAe        11
# PosA         8
# RRNn         5
# RRNe         2
# Name: Condition1, dtype: int64
#
#
#  Column Name: Condition2 Counts: Norm      1445
# Feedr        6
# PosN         2
# RRNn         2
# Artery       2
# PosA         1
# RRAe         1
# RRAn         1
# Name: Condition2, dtype: int64
#
#
#  Column Name: BldgType Counts: 1Fam      1220
# TwnhsE     114
# Duplex      52
# Twnhs       43
# 2fmCon      31
# Name: BldgType, dtype: int64
#
#
#  Column Name: HouseStyle Counts: 1Story    726
# 2Story    445
# 1.5Fin    154
# SLvl       65
# SFoyer     37
# 1.5Unf     14
# 2.5Unf     11
# 2.5Fin      8
# Name: HouseStyle, dtype: int64
#
#
#  Column Name: OverallQual Counts: 5     397
# 6     374
# 7     319
# 8     168
# 4     116
# 9      43
# 3      20
# 10     18
# 2       3
# 1       2
# Name: OverallQual, dtype: int64
#
#
#  Column Name: OverallCond Counts: 5    821
# 6    252
# 7    205
# 8     72
# 4     57
# 3     25
# 9     22
# 2      5
# 1      1
# Name: OverallCond, dtype: int64
#
#
#  Column Name: YearBuilt Counts: 2006    67
# 2005    64
# 2004    54
# 2007    49
# 2003    45
#         ..
# 1904     1
# 1898     1
# 1893     1
# 1882     1
# 2010     1
# Name: YearBuilt, Length: 112, dtype: int64
#
#
#  Column Name: YearRemodAdd Counts: 1950    178
# 2006     97
# 2007     76
# 2005     73
# 2004     62
#        ...
# 2010      6
# 1983      5
# 1986      5
# 1952      5
# 1951      4
# Name: YearRemodAdd, Length: 61, dtype: int64
#
#
#  Column Name: RoofStyle Counts: Gable      1141
# Hip         286
# Flat         13
# Gambrel      11
# Mansard       7
# Shed          2
# Name: RoofStyle, dtype: int64
#
#
#  Column Name: RoofMatl Counts: CompShg    1434
# Tar&Grv      11
# WdShngl       6
# WdShake       5
# Membran       1
# ClyTile       1
# Metal         1
# Roll          1
# Name: RoofMatl, dtype: int64
#
#
#  Column Name: Exterior1st Counts: VinylSd    515
# HdBoard    222
# MetalSd    220
# Wd Sdng    206
# Plywood    108
# CemntBd     61
# BrkFace     50
# WdShing     26
# Stucco      25
# AsbShng     20
# BrkComm      2
# Stone        2
# CBlock       1
# AsphShn      1
# ImStucc      1
# Name: Exterior1st, dtype: int64
#
#
#  Column Name: Exterior2nd Counts: VinylSd    504
# MetalSd    214
# HdBoard    207
# Wd Sdng    197
# Plywood    142
# CmentBd     60
# Wd Shng     38
# Stucco      26
# BrkFace     25
# AsbShng     20
# ImStucc     10
# Brk Cmn      7
# Stone        5
# AsphShn      3
# CBlock       1
# Other        1
# Name: Exterior2nd, dtype: int64
#
#
#  Column Name: MasVnrType Counts: None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64
#
#
#  Column Name: MasVnrArea Counts: 0.0      861
# 108.0      8
# 72.0       8
# 180.0      8
# 16.0       7
#         ...
# 31.0       1
# 366.0      1
# 528.0      1
# 894.0      1
# 415.0      1
# Name: MasVnrArea, Length: 327, dtype: int64
#
#
#  Column Name: ExterQual Counts: TA    906
# Gd    488
# Ex     52
# Fa     14
# Name: ExterQual, dtype: int64
#
#
#  Column Name: ExterCond Counts: TA    1282
# Gd     146
# Fa      28
# Ex       3
# Po       1
# Name: ExterCond, dtype: int64
#
#
#  Column Name: Foundation Counts: PConc     647
# CBlock    634
# BrkTil    146
# Slab       24
# Stone       6
# Wood        3
# Name: Foundation, dtype: int64
#
#
#  Column Name: BsmtQual Counts: TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: BsmtQual, dtype: int64
#
#
#  Column Name: BsmtCond Counts: TA    1311
# Gd      65
# Fa      45
# Po       2
# Name: BsmtCond, dtype: int64
#
#
#  Column Name: BsmtExposure Counts: No    953
# Av    221
# Gd    134
# Mn    114
# Name: BsmtExposure, dtype: int64
#
#
#  Column Name: BsmtFinType1 Counts: Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: BsmtFinType1, dtype: int64
#
#
#  Column Name: BsmtFinSF1 Counts: 0       467
# 24       12
# 16        9
# 20        5
# 686       5
#        ...
# 535       1
# 534       1
# 532       1
# 522       1
# 2096      1
# Name: BsmtFinSF1, Length: 637, dtype: int64
#
#
#  Column Name: BsmtFinType2 Counts: Unf    1256
# Rec      54
# LwQ      46
# BLQ      33
# ALQ      19
# GLQ      14
# Name: BsmtFinType2, dtype: int64
#
#
#  Column Name: BsmtFinSF2 Counts: 0       1293
# 180        5
# 374        3
# 117        2
# 391        2
#         ...
# 215        1
# 211        1
# 210        1
# 208        1
# 1474       1
# Name: BsmtFinSF2, Length: 144, dtype: int64
#
#
#  Column Name: BsmtUnfSF Counts: 0       118
# 728       9
# 384       8
# 572       7
# 600       7
#        ...
# 549       1
# 548       1
# 545       1
# 543       1
# 2046      1
# Name: BsmtUnfSF, Length: 780, dtype: int64
#
#
#  Column Name: TotalBsmtSF Counts: 0       37
# 864     35
# 672     17
# 912     15
# 1040    14
#         ..
# 1210     1
# 727      1
# 1205     1
# 1203     1
# 2046     1
# Name: TotalBsmtSF, Length: 721, dtype: int64
#
#
#  Column Name: Heating Counts: GasA     1428
# GasW       18
# Grav        7
# Wall        4
# OthW        2
# Floor       1
# Name: Heating, dtype: int64
#
#
#  Column Name: HeatingQC Counts: Ex    741
# TA    428
# Gd    241
# Fa     49
# Po      1
# Name: HeatingQC, dtype: int64
#
#
#  Column Name: CentralAir Counts: Y    1365
# N      95
# Name: CentralAir, dtype: int64
#
#
#  Column Name: Electrical Counts: SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64
#
#
#  Column Name: 1stFlrSF Counts: 864     25
# 1040    16
# 912     14
# 848     12
# 894     12
#         ..
# 1061     1
# 1058     1
# 1051     1
# 1047     1
# 2046     1
# Name: 1stFlrSF, Length: 753, dtype: int64
#
#
#  Column Name: 2ndFlrSF Counts: 0       829
# 728      10
# 504       9
# 672       8
# 546       8
#        ...
# 812       1
# 811       1
# 473       1
# 475       1
# 1872      1
# Name: 2ndFlrSF, Length: 417, dtype: int64
#
#
#  Column Name: LowQualFinSF Counts: 0      1434
# 80        3
# 360       2
# 392       1
# 528       1
# 515       1
# 514       1
# 513       1
# 481       1
# 479       1
# 473       1
# 420       1
# 397       1
# 390       1
# 53        1
# 384       1
# 371       1
# 234       1
# 232       1
# 205       1
# 156       1
# 144       1
# 120       1
# 572       1
# Name: LowQualFinSF, dtype: int64
#
#
#  Column Name: GrLivArea Counts: 864     22
# 1040    14
# 894     11
# 848     10
# 1456    10
#         ..
# 2792     1
# 2794     1
# 1349     1
# 1347     1
# 2054     1
# Name: GrLivArea, Length: 861, dtype: int64
#
#
#  Column Name: BsmtFullBath Counts: 0    856
# 1    588
# 2     15
# 3      1
# Name: BsmtFullBath, dtype: int64
#
#
#  Column Name: BsmtHalfBath Counts: 0    1378
# 1      80
# 2       2
# Name: BsmtHalfBath, dtype: int64
#
#
#  Column Name: FullBath Counts: 2    768
# 1    650
# 3     33
# 0      9
# Name: FullBath, dtype: int64
#
#
#  Column Name: HalfBath Counts: 0    913
# 1    535
# 2     12
# Name: HalfBath, dtype: int64
#
#
#  Column Name: BedroomAbvGr Counts: 3    804
# 2    358
# 4    213
# 1     50
# 5     21
# 6      7
# 0      6
# 8      1
# Name: BedroomAbvGr, dtype: int64
#
#
#  Column Name: KitchenAbvGr Counts: 1    1392
# 2      65
# 3       2
# 0       1
# Name: KitchenAbvGr, dtype: int64
#
#
#  Column Name: KitchenQual Counts: TA    735
# Gd    586
# Ex    100
# Fa     39
# Name: KitchenQual, dtype: int64
#
#
#  Column Name: TotRmsAbvGrd Counts: 6     402
# 7     329
# 5     275
# 8     187
# 4      97
# 9      75
# 10     47
# 11     18
# 3      17
# 12     11
# 2       1
# 14      1
# Name: TotRmsAbvGrd, dtype: int64
#
#
#  Column Name: Functional Counts: Typ     1360
# Min2      34
# Min1      31
# Mod       15
# Maj1      14
# Maj2       5
# Sev        1
# Name: Functional, dtype: int64
#
#
#  Column Name: Fireplaces Counts: 0    690
# 1    650
# 2    115
# 3      5
# Name: Fireplaces, dtype: int64
#
#
#  Column Name: FireplaceQu Counts: Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64
#
#
#  Column Name: GarageType Counts: Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64
#
#
#  Column Name: GarageYrBlt Counts: 2005.0    65
# 2006.0    59
# 2004.0    53
# 2003.0    50
# 2007.0    49
#           ..
# 1906.0     1
# 1908.0     1
# 1933.0     1
# 1900.0     1
# 1927.0     1
# Name: GarageYrBlt, Length: 97, dtype: int64
#
#
#  Column Name: GarageFinish Counts: Unf    605
# RFn    422
# Fin    352
# Name: GarageFinish, dtype: int64
#
#
#  Column Name: GarageCars Counts: 2    824
# 1    369
# 3    181
# 0     81
# 4      5
# Name: GarageCars, dtype: int64
#
#
#  Column Name: GarageArea Counts: 0       81
# 440     49
# 576     47
# 240     38
# 484     34
#         ..
# 671      1
# 342      1
# 673      1
# 675      1
# 1418     1
# Name: GarageArea, Length: 441, dtype: int64
#
#
#  Column Name: GarageQual Counts: TA    1311
# Fa      48
# Gd      14
# Ex       3
# Po       3
# Name: GarageQual, dtype: int64
#
#
#  Column Name: GarageCond Counts: TA    1326
# Fa      35
# Gd       9
# Po       7
# Ex       2
# Name: GarageCond, dtype: int64
#
#
#  Column Name: PavedDrive Counts: Y    1340
# N      90
# P      30
# Name: PavedDrive, dtype: int64
#
#
#  Column Name: WoodDeckSF Counts: 0      761
# 192     38
# 100     36
# 144     33
# 120     31
#       ...
# 103      1
# 269      1
# 98       1
# 97       1
# 857      1
# Name: WoodDeckSF, Length: 274, dtype: int64
#
#
#  Column Name: OpenPorchSF Counts: 0      656
# 36      29
# 48      22
# 20      21
# 45      19
#       ...
# 141      1
# 137      1
# 135      1
# 134      1
# 547      1
# Name: OpenPorchSF, Length: 202, dtype: int64
#
#
#  Column Name: EnclosedPorch Counts: 0      1252
# 112      15
# 96        6
# 120       5
# 192       5
#        ...
# 170       1
# 169       1
# 67        1
# 68        1
# 552       1
# Name: EnclosedPorch, Length: 120, dtype: int64
#
#
#  Column Name: 3SsnPorch Counts: 0      1436
# 168       3
# 216       2
# 144       2
# 180       2
# 407       1
# 320       1
# 304       1
# 290       1
# 245       1
# 238       1
# 182       1
# 196       1
# 23        1
# 162       1
# 153       1
# 140       1
# 130       1
# 96        1
# 508       1
# Name: 3SsnPorch, dtype: int64
#
#
#  Column Name: ScreenPorch Counts: 0      1344
# 192       6
# 120       5
# 224       5
# 180       4
#        ...
# 175       1
# 178       1
# 40        1
# 185       1
# 480       1
# Name: ScreenPorch, Length: 76, dtype: int64
#
#
#  Column Name: PoolArea Counts: 0      1453
# 480       1
# 512       1
# 519       1
# 555       1
# 576       1
# 648       1
# 738       1
# Name: PoolArea, dtype: int64
#
#
#  Column Name: PoolQC Counts: Gd    3
# Ex    2
# Fa    2
# Name: PoolQC, dtype: int64
#
#
#  Column Name: Fence Counts: MnPrv    157
# GdPrv     59
# GdWo      54
# MnWw      11
# Name: Fence, dtype: int64
#
#
#  Column Name: MiscFeature Counts: Shed    49
# Othr     2
# Gar2     2
# TenC     1
# Name: MiscFeature, dtype: int64
#
#
#  Column Name: MiscVal Counts: 0        1408
# 400        11
# 500         8
# 700         5
# 450         4
# 600         4
# 2000        4
# 480         2
# 1200        2
# 2500        1
# 350         1
# 560         1
# 54          1
# 620         1
# 8300        1
# 800         1
# 1150        1
# 15500       1
# 1300        1
# 1400        1
# 3500        1
# Name: MiscVal, dtype: int64
#
#
#  Column Name: MoSold Counts: 6     253
# 7     234
# 5     204
# 4     141
# 8     122
# 3     106
# 10     89
# 11     79
# 9      63
# 12     59
# 1      58
# 2      52
# Name: MoSold, dtype: int64
#
#
#  Column Name: YrSold Counts: 2009    338
# 2007    329
# 2006    314
# 2008    304
# 2010    175
# Name: YrSold, dtype: int64
#
#
#  Column Name: SaleType Counts: WD       1267
# New       122
# COD        43
# ConLD       9
# ConLw       5
# ConLI       5
# CWD         4
# Oth         3
# Con         2
# Name: SaleType, dtype: int64
#
#
#  Column Name: SaleCondition Counts: Normal     1198
# Partial     125
# Abnorml     101
# Family       20
# Alloca       12
# AdjLand       4
# Name: SaleCondition, dtype: int64
#
#
#  Column Name: SalePrice Counts: 140000    20
# 135000    17
# 155000    14
# 145000    14
# 190000    13
#           ..
# 337000     1
# 412500     1
# 306000     1
# 195400     1
# 206000     1
# Name: SalePrice, Length: 663, dtype: int64

# %%
y = home_data["SalePrice"]
print(y.value_counts())
# Check your answer
step_1.check()
# Out:
# 140000    20
# 135000    17
# 155000    14
# 145000    14
# 190000    13
#           ..
# 337000     1
# 412500     1
# 306000     1
# 195400     1
# 206000     1
# Name: SalePrice, Length: 663, dtype: int64
# Correct

# %%
# The lines below will show you a hint or the solution.
# step_1.hint() 
#step_1.solution()

# %% [markdown]
# ## Step 2: Create X
# Now you will create a DataFrame called `X` holding the predictive features.
#
# Since you want only some columns from the original data, you'll first create a list with the names of the columns you want in `X`.
#
# You'll use just the following columns in the list (you can copy and paste the whole list to save some typing, though you'll still need to add quotes):
#     * LotArea
#     * YearBuilt
#     * 1stFlrSF
#     * 2ndFlrSF
#     * FullBath
#     * BedroomAbvGr
#     * TotRmsAbvGrd
#
# After you've created that list of features, use it to create the DataFrame that you'll use to fit the model.

# %%
# Create the list of features below
feature_names = ['LotArea','YearBuilt', '1stFlrSF', '2ndFlrSF', 'FullBath', 'BedroomAbvGr', 'TotRmsAbvGrd']

# Select data corresponding to features in feature_names
X = home_data[feature_names]

# Check your answer
step_2.check()
# Out:
# Correct

# %%
home_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
# step_2.hint()
# step_2.solution()

# %% [markdown]
# ## Review Data
# Before building a model, take a quick look at **X** to verify it looks sensible

# %%
# Review data
# print description or statistics from X
print(X.describe())

# print the top few lines
#print(X.head())
# Out:
#              LotArea    YearBuilt     1stFlrSF     2ndFlrSF     FullBath  \
# count    1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean    10516.828082  1971.267808  1162.626712   346.992466     1.565068
# std      9981.264932    30.202904   386.587738   436.528436     0.550916
# min      1300.000000  1872.000000   334.000000     0.000000     0.000000
# 25%      7553.500000  1954.000000   882.000000     0.000000     1.000000
# 50%      9478.500000  1973.000000  1087.000000     0.000000     2.000000
# 75%     11601.500000  2000.000000  1391.250000   728.000000     2.000000
# max    215245.000000  2010.000000  4692.000000  2065.000000     3.000000
#
#        BedroomAbvGr  TotRmsAbvGrd
# count   1460.000000   1460.000000
# mean       2.866438      6.517808
# std        0.815778      1.625393
# min        0.000000      2.000000
# 25%        2.000000      5.000000
# 50%        3.000000      6.000000
# 75%        3.000000      7.000000
# max        8.000000     14.000000

# %% [markdown]
# ## Step 3: Specify and Fit Model
# Create a `DecisionTreeRegressor` and save it iowa_model. Ensure you've done the relevant import from sklearn to run this command.
#
# Then fit the model you just created using the data in `X` and `y` that you saved above.

# %%
from sklearn.tree import DecisionTreeRegressor
#specify the model. 
#For model reproducibility, set a numeric value for random_state when specifying the model
iowa_model = DecisionTreeRegressor(random_state=1)

# Fit the model
iowa_model.fit(X,y)

# Check your answer
step_3.check()
# Out:
# Correct

# %%
# step_3.hint()
# step_3.solution()

# %% [markdown]
# ## Step 4: Make Predictions
# Make predictions with the model's `predict` command using `X` as the data. Save the results to a variable called `predictions`.

# %%
predictions = iowa_model.predict(X)
print(predictions)

# Check your answer
step_4.check()
# Out:
# [208500. 181500. 223500. ... 266500. 142125. 147500.]
# Correct

# %%
# step_4.hint()
# step_4.solution()

# %% [markdown]
# ## Think About Your Results
#
# Use the `head` method to compare the top few predictions to the actual home values (in `y`) for those same homes. Anything surprising?

# %%
# You can write code in this cell
predictions = pd.Series(predictions)
print(predictions.head())
print("\n\n")
print(y.head())
# Out:
# 0    208500.0
# 1    181500.0
# 2    223500.0
# 3    140000.0
# 4    250000.0
# dtype: float64
#
#
#
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %% [markdown]
# It's natural to ask how accurate the model's predictions will be and how you can improve that. That will be you're next step.
#
# # Keep Going
#
# You are ready for **[Model Validation](https://www.kaggle.com/dansbecker/model-validation).**

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [Learn Discussion forum](https://www.kaggle.com/learn-forum/161285) to chat with other Learners.*
